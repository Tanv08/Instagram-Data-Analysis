# %%
import pandas as pd
import numpy as np

# %%
df_insta = pd.read_csv(r'C:\Users\15512\Desktop\Marketing Analytics\instagram_global_top_1000.csv')
df_insta.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#    Followers Audience Country  Authentic engagement  Engagement avg  Scraped
# 0  400100000            India               7800000         9500000  50:24.8
# 1  308800000    United States               6200000        10100000  50:24.8
# ...

# %%
# looking at info for dataframe

df_insta.info
# Out:
# <bound method DataFrame.info of     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
# using describe to get the basic statistics of the dataframe

df_insta.describe()
# Out:
#               Rank     Followers  Authentic engagement  Engagement avg
# count  1000.000000  1.000000e+03          1.000000e+03    1.000000e+03
# mean    500.500000  2.483610e+07          6.491228e+05    8.653886e+05
# std     288.819436  3.872143e+07          1.098804e+06    1.267515e+06
# min       1.000000  2.800000e+06          0.000000e+00    5.200000e+04
# 25%     250.750000  9.000000e+06          2.091000e+05    3.086000e+05
# 50%     500.500000  1.440000e+07          3.637000e+05    5.239000e+05
# 75%     750.250000  2.565000e+07          6.832500e+05    9.508000e+05
# max    1000.000000  4.696000e+08          1.340000e+07    1.340000e+07

# %%
# returning the relative frequency of audience country elements
# can see that 28% of the top 1,000 influencers have the United States as their audience country

df_insta['Audience Country'].value_counts(normalize=True).round(2)
# Out:
# United States           0.28
# Brazil                  0.16
# India                   0.14
# Indonesia               0.13
# Mexico                  0.05
# Spain                   0.03
# Russia                  0.03
# Argentina               0.02
# Iran                    0.02
# United Kingdom          0.02
# Turkey                  0.02
# Italy                   0.02
# South Korea             0.01
# Colombia                0.01
# Philippines             0.01
# France                  0.01
# Egypt                   0.01
# Germany                 0.01
# Nigeria                 0.00
# Thailand                0.00
# Iraq                    0.00
# Morocco                 0.00
# Japan                   0.00
# Saudi Arabia            0.00
# Kazakhstan              0.00
# Syria                   0.00
# China                   0.00
# Algeria                 0.00
# United Arab Emirates    0.00
# Poland                  0.00
# Chile                   0.00
# ...

# %%
# creating a pivot table to show statistics for categories

df_insta.pivot_table(index="Category", values="Followers", aggfunc=['mean', 'sum', 'min', 'max'], sort=False)
# Out:
#                                                mean         sum        min  \
#                                           Followers   Followers  Followers
# Category
# Sports with a ball                     3.225825e+07  3322600000    5400000
# Fashion|Modeling|Beauty                3.088000e+08   308800000  308800000
# Sports with a ball|Family              1.730500e+08   346100000   39800000
# Modeling|Fashion                       6.622500e+07   264900000   11400000
# Music|Lifestyle                        4.848000e+07   484800000    7600000
# ...                                             ...         ...        ...
# Photography|Lifestyle                  7.900000e+06     7900000    7900000
# Modeling|Music                         6.800000e+06     6800000    6800000
# Beauty|Art|Artists|Modeling            1.360000e+07    13600000   13600000
# Humor|Fun|Happiness|Shows|Art|Artists  1.570000e+07    15700000   15700000
# ...

# %%
# creating a new dataframe just for the United States 

df_usa = df_insta[df_insta['Audience Country'] == 'United States']
df_usa.head()
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 4     All     5    selenagomez         Selena Gomez
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/                  Music|Lifestyle
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
#
#    Followers Audience Country  Authentic engagement  Engagement avg  Scraped
# 1  308800000    United States               6200000        10100000  50:24.8
# ...

# %%
# turning the floats to ints

df_usa = df_usa.astype({"Followers":"int","Authentic engagement":"int","Engagement avg":"int"})
df_usa.head()
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 4     All     5    selenagomez         Selena Gomez
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/                  Music|Lifestyle
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
#
#    Followers Audience Country  Authentic engagement  Engagement avg  Scraped
# 1  308800000    United States               6200000        10100000  50:24.8
# ...

# %%
# pivot table to show statistics on category followers in the United States

df_usa.pivot_table(index="Category", values="Followers", aggfunc=['mean', 'sum', 'min', 'max'], sort=False)
# Out:
#                                                        mean        sum  \
#                                                   Followers  Followers
# Category
# Fashion|Modeling|Beauty                         308800000.0  308800000
# Modeling|Fashion                                217800000.0  217800000
# Music|Lifestyle                                 105900000.0  317700000
# Cinema|Actors/actresses|Fashion                 127800000.0  127800000
# Fashion|Beauty                                  284900000.0  284900000
# ...                                                     ...        ...
# Clothing|Outfits                                  6700000.0    6700000
# Accessories|Jewellery|Clothing|Outfits|Fashion   47100000.0   47100000
# Modeling|Music                                    6800000.0    6800000
# Beauty|Art|Artists|Modeling                      13600000.0   13600000
# Literature|Journalism                             8100000.0    8100000
#
# ...

# %%
df_usa.pivot_table(index="Category", values="Engagement avg", aggfunc=['mean', 'sum', 'min', 'max'], sort=False)
# Out:
#                                                          mean            sum  \
#                                                Engagement avg Engagement avg
# Category
# Fashion|Modeling|Beauty                          1.010000e+07       10100000
# Modeling|Fashion                                 5.400000e+06        5400000
# Music|Lifestyle                                  1.580733e+06        4742200
# Cinema|Actors/actresses|Fashion                  7.800000e+06        7800000
# Fashion|Beauty                                   3.300000e+06        3300000
# ...                                                       ...            ...
# Clothing|Outfits                                 3.925000e+05         392500
# Accessories|Jewellery|Clothing|Outfits|Fashion   5.400000e+04          54000
# Modeling|Music                                   3.666000e+05         366600
# Beauty|Art|Artists|Modeling                      1.806000e+05         180600
# ...

# %%
# showing the categories with the most followers

topfollowers = df_usa.nlargest(10,'Followers')

topfollowers.pivot_table(index="Category", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                                                     sum
#                                               Followers
# Category
# Fashion|Modeling|Beauty                       308800000
# Music|Lifestyle                               295800000
# Music                                         294100000
# Fashion|Beauty                                284900000
# Music|Fashion                                 237200000
# Clothing|Outfits|Lifestyle                    219400000
# Modeling|Fashion                              217800000
# Nature  landscapes|Science|Photography        206600000
# Fitness|Gym|Shopping|Retail|Clothing|Outfits  199000000
# Music|Cinema|Actors/actresses                 194900000

# %%
# creating dataframe for top 20 followers

top20followers = df_usa.nlargest(20,'Followers')

# %%
# showing the categories with the most avg audience engagement

topengagementavg = df_usa.nlargest(20,'Engagement avg')

topengagementavg.pivot_table(index="Category", values="Engagement avg", sort=False)
# Out:
#                                  Engagement avg
# Category
# Fashion|Modeling|Beauty                10100000
# Cinema|Actors/actresses|Fashion         7800000
# Cinema|Actors/actresses                 5250000
# Music                                   4200000
# Modeling|Fashion                        5400000
# Music|Lifestyle                         3600000
# Music|Fashion                           3100000
# Fashion|Beauty                          3300000
# Music|Beauty                            2800000
# Lifestyle|Shows                         2400000

# %%
# showing the categories with the most authentic audience engagement

topengagement = df_usa.nlargest(20,'Authentic engagement')

topengagement.pivot_table(index="Category", values="Authentic engagement", sort=False)
# Out:
#                                  Authentic engagement
# Category
# Fashion|Modeling|Beauty                       6200000
# Cinema|Actors/actresses                       3950000
# Cinema|Actors/actresses|Fashion               5800000
# Music                                         3200000
# Modeling|Fashion                              3400000
# Music|Lifestyle                               2700000
# Music|Fashion                                 2150000
# Fashion|Beauty                                2200000
# Lifestyle|Shows                               1900000
# Music|Beauty                                  1700000

# %%
# creating a new fashion category dataframe to include all of the subsets

fashion = df_usa[df_usa['Category'].str.contains('Fashion', na=False)]
fashion.head()
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
# 7     All     8        beyonce             Beyoncé
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
# 7        https://www.instagram.com/beyonce/                    Music|Fashion
#
#    Followers Audience Country  Authentic engagement  Engagement avg  Scraped
# 1  308800000    United States               6200000        10100000  50:24.8
# ...

# %%
# import pyplot package

from matplotlib import pyplot as plt

# %%
# plotting followers

plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers.Category, topfollowers.Followers, label='Followers', width=0.8, color='skyblue')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 10 Categories by Followers", fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(axis="y", style='plain')

# %%
# plotting followers

plt.figure(figsize=(12,8))
fig2 = plt.bar(top20followers.Category, top20followers.Followers, label='Followers', width=0.8, color='skyblue')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 20 Categories by Followers", fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(axis="y", style='plain')

# %%
# plotting the number of accounts between 0 and 60 million followers

plt.figure(figsize=(12,8))
plt.hist(df_usa.Followers, color='skyblue', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the US', fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(style='plain')

# %% [markdown]
# Analysis Insights

# %% [markdown]
# Found that 28% of the top 1,000 Instagram influencers have the United States as their audience country.

# %% [markdown]
# Interestingly, several of the top ranked Instagram accounts globally were under the category "Sports with a ball", but this category was not found in the top followers or audience engagement for the United States.

# %% [markdown]
# The top 10 follower categories in the United States were: Fashion|Modeling|Beauty, Music|Lifestyle, Music, Fashion|Beauty, Music|Fashion, Clothing|Outfits|Lifestyle, Modeling|Fashion, Nature landscapes|Science|Photography, Fitness|Gym|Shopping|Retail|Clothing|Outfits, Music|Cinema|Actors/actresses.

# %% [markdown]
# 40% of these groups have "Fashion", 40% have "Music", 20% have "Modeling", 20% have "Beauty", 20% have "Lifestyle", 20% have "Clothing", and 20% have "Outfits".

# %% [markdown]
# The top 10 categories have a total of 2,458,500,000 followers. 42.66% of these are in a category involving "Fashion" and 41.57% are in a category involving "Music".

# %% [markdown]
# The top categories for engagement averages and authentic engagement were mostly consistent with the top followers. However, these categories also included "Cinema" and "Actors/Actresses".

# %% [markdown]
# Recommendations

# %% [markdown]
# Most of the top Instagram influencers are in a category of Fashion or Music. Many of the top categories also include Cinema, Acting, Modeling, Beauty, and Lifestyle. Categories involving Fashion had the highest followers and engagement. Therefore, Fashion should be considered the top category for Instagram influencers in the United States.
